# %%
import pandas as pd
df = pd.read_csv("../stage6/step3.csv")

# %%
import pandas as pd
from tqdm.notebook import tqdm
mimic4 = pd.read_csv("../raw_data/mimic4.csv")
mimic4.sort_values(by='charttime', ascending=True, inplace=True)

# %%
tmp = mimic4[mimic4["subject_id"].isin(list(df["Patient_ID"].values))]

# %%
tmp.to_csv("stage6_filtered_df.csv",index=False)

# %%
df
# Out:
#      Index  Num_Notes  Patient_ID  \
# 0        1          1    11350221
# 1        2          1    17807085
# 2        3          1    16447217
# 3        4          1    17826767
# 4        5          1    11616741
# ..     ...        ...         ...
# 145    146          2    18160798
# 146    147          2    10177094
# 147    148          2    18346141
# 148    149          2    18359614
# 149    150          2    18003464
#
#                                               Question  \
# 0    What were the substance use habits of the pati...
# 1    What was the key physical restriction advised ...
# 2    What were the patient's past medical history a...
# 3    What type of surgery did this patient have, an...
# 4    Has there been any major surgical or invasive ...
# ..                                                 ...
# 145  What were the treatments given to the patient ...
# 146  What was the method used for treating the pati...
# 147  What was the result of the patient's full GTT ...
# 148  What medical treatment was prescribed for pati...
# 149  What surgical procedure has the patient underg...
#
#                                               Choice_A  \
# 0    The patient had a history of marijuana and her...
# 1    The patient was advised to refrain from any ph...
# 2    The patient had a history of stroke and diabet...
# 3    The patient underwent an appendectomy due to a...
# 4    The patient had a total hip replacement surger...
# ..                                                 ...
# 145  The patient was given ibuprofen and Xulane, fo...
# 146  The patient was treated with a multi-dose regi...
# 147  The full GTT test was not done and the patient...
# 148  The patient was administered dopamine and morp...
# 149  The patient underwent a tonsillectomy and expe...
#
#                                               Choice_B  \
# 0    The patient was found to have a history of tob...
# 1    The patient was instructed to avoid bending or...
# 2    The patient's medical history is comprised of ...
# 3    The patient had an ACL surgery due to intense ...
# 4    The patient had a right total knee arthroplast...
# ..                                                 ...
# 145  During her first admission, the patient was tr...
# 146  The patient was administered antibiotics durin...
# 147  The full GTT test showed that the patient had ...
# 148  For pain management, the patient was given Dil...
# 149  A cyberknife treatment for prostate cancer was...
#
#                                               Choice_C  \
# 0    The patient abused methamphetamine and has alr...
# 1    The patient was advised to strictly follow die...
# 2    Historical ailments for the patient consisted ...
# 3    The patient underwent a T10-L2 posterior spina...
# 4    The patient was treated for hypertension, and ...
# ..                                                 ...
# 145  Treatment during the first admission included ...
# 146  The patient received a multi-dose regimen of m...
# 147  The full GTT test was positive for gestational...
# 148  For the fall in 2113, the patient was prescrib...
# 149  The patient underwent cystoscopy and transuret...
#
#                                               Choice_D  \
# 0    The patient has a history of heavy drinking bu...
# 1    The patient was told not to expose himself to ...
# 2    The patient had a history of hypertension and ...
# 3    The patient had a knee replacement surgery due...
# 4    The patient had a gall-bladder removal surgery...
# ..                                                 ...
# 145  In her first admission, the patient was treate...
# 146  The patient was treated with a multi-dose of c...
# 147  The full GTT test found the patient to be at r...
# 148  IV fluids and antibiotics were used to manage ...
# 149  Surgical repair of the left tibia fracture was...
#
#                                               Choice_E Answer  \
# 0    The patient used psychedelic drugs frequently,...      B
# 1      The patient was told to avoid drinking alcohol.      B
# 2    The patient previously suffered from epilepsy ...      B
# 3    The patient underwent an emergency surgery fol...      C
# 4    The patient had cardiac surgery in the past, a...      B
# ..                                                 ...    ...
# 145  The patient was initially treated with dicloxa...      C
# 146  The patient was treated with a multi-dose of a...      C
# 147  The full GTT test did not show any significant...      C
# 148  For pain management, the patient was given pre...      C
# 149  The patient was operated for the resection of ...      C
#
#                                                 Reason
# 0    The discharge summary states that the patient ...
# 1    The discharge summary explicitly mentions two ...
# 2    The correct answer is B because it mentions th...
# 3    The patient's discharge summary indicates that...
# 4    The patient's complaint at the time of admissi...
# ..                                                 ...
# 145  The patient was initially treated with a 10-da...
# 146  In the first admission, the patient was given ...
# 147  In the discharge summary [note 2], it is state...
# 148  According to the discharge summaries, during t...
# 149  According to the note charted on 2146-05-08, t...
#
# [150 rows x 11 columns]

# %%
df.to_csv("stage6_step3.csv",index=False)
