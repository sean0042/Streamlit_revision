# %%
import pandas as pd
df = pd.read_csv("../stage4/step3.csv")

# %%
import pandas as pd
from tqdm.notebook import tqdm
mimic4 = pd.read_csv("../raw_data/mimic4.csv")
mimic4.sort_values(by='charttime', ascending=True, inplace=True)

# %%
tmp = mimic4[mimic4["subject_id"].isin(list(df["Patient_ID"].values))]

# %%
tmp.to_csv("stage4_filtered_df.csv",index=False)

# %%
df
# Out:
#      Index  Num_Notes  Patient_ID  \
# 0        1          1    16126307
# 1        2          1    17995708
# 2        3          1    11419951
# 3        4          1    15820880
# 4        5          1    17670977
# ..     ...        ...         ...
# 145    146          1    16840956
# 146    147          1    15465589
# 147    148          1    12346890
# 148    149          1    17492675
# 149    150          1    12988383
#
#                                               Question  \
# 0    What potential factors could have contributed ...
# 1    What was found in the level of neutrophils and...
# 2    What were the abnormal findings of the Echocar...
# 3    What was the final diagnosis of the patient an...
# 4    What was the infection identified in the patie...
# ..                                                 ...
# 145  What was the provisional diagnosis of the lesi...
# 146  What medications was the patient prescribed on...
# 147  What was the primary surgical or invasive proc...
# 148  What were the results of the patient's exercis...
# 149  What was the cause of the patient's pneumonia ...
#
#                                               Choice_A  \
# 0     The patient was experiencing heart palpitations.
# 1    The patient showed an increased white blood ce...
# 2    There was no evidence of any issues in the Ech...
# 3    The patient was diagnosed with a bacterial inf...
# 4    The patient was diagnosed with a respiratory i...
# ..                                                 ...
# 145  The lesion was diagnosed as a left occipital i...
# 146  The patient was advised to take celexa and ser...
# 147  The patient had a stent trial with 3 metal ste...
# 148  The patient exercised insufficiently and displ...
# 149  The patient's pneumonia was caused by an aller...
#
#                                               Choice_B  \
# 0    The patient contracted E.coli bacteriuria prio...
# 1    The patient showed a high hematocrit level, su...
# 2    The Echocardiogram reported thickened mitral v...
# 3    The patient was diagnosed with central nervous...
# 4    The patient was diagnosed with hyperlipidemia ...
# ..                                                 ...
# 145  The lesion diagnosed was a hyperdensity in the...
# 146  The patient has been prescribed wellbutrin and...
# 147  The patient had a biopsy which showed noncasea...
# 148  The patient's stress test showed a high risk o...
# 149  The patient's pneumonia was caused by inhalati...
#
#                                               Choice_C  \
# 0    The patient had a history of severe pulmonary ...
# 1    The patient showed a decreased level of neutro...
# 2    According to the Echocardiogram, the patient h...
# 3    The patient was diagnosed with viral syndrome,...
# 4    The patient was diagnosed with a urinary tract...
# ..                                                 ...
# 145  The lesion was diagnosed as a R head and eye d...
# 146  The medications prescribed on discharge were w...
# 147  The patient underwent a thoracotomy and trache...
# 148  The test demonstrated that the patient had dif...
# 149  The patient's pneumonia was caused by an aller...
#
#                                               Choice_D  \
# 0    The patient had a history of severe Aortic ste...
# 1    The patient showed a high level of creatinine,...
# 2    The Echocardiogram revealed a history of heart...
# 3    The patient was diagnosed with subarachnoid he...
# 4    The patient was diagnosed with benign prostate...
# ..                                                 ...
# 145  The lesion observed in the patient's brain was...
# 146  The patient has been administered celexa and q...
# 147  The patient was treated with chest ___, nebuli...
# 148  The patient showed uniform tracer uptake throu...
# 149  The patient's pneumonia was caused by her asth...
#
#                                               Choice_E Answer  \
# 0    The patient had a high glucose level in the bl...      D
# 1    The patient showed a high level of glucose, in...      C
# 2    According to the Echocardiogram, the patient's...      B
# 3    The patient was diagnosed with endocarditis as...      C
# 4    The patient was diagnosed with gout and was ma...      C
# ..                                                 ...    ...
# 145  The lesion was diagnosed as a L corneal infect...      A
# 146  The patient was prescribed citalopram and quet...      A
# 147         The patient underwent bronchothermoplasty.      C
# 148  The test revealed that the patient had an abno...      D
# 149  The patient's pneumonia was caused by her seiz...      B
#
#                                                 Reason
# 0    The correct answer is D, "The patient had a hi...
# 1    The discharge summary shows a decreased level ...
# 2    The correct response is found in the results o...
# 3    The final diagnosis of the patient was viral s...
# 4    According to the given discharge summary, the ...
# ..                                                 ...
# 145  The discharge summary explicitly mentions that...
# 146  Towards the end of the note, under the subhead...
# 147  Option C is the correct answer, as on the date...
# 148  In the discharge summary, it is noted under th...
# 149  The notes indicate that the patient's pneumoni...
#
# [150 rows x 11 columns]

# %%
df.to_csv("stage4_step3.csv",index=False)
