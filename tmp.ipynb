# %%
import pandas as pd
df = pd.read_csv("../stage3/step3.csv")

# %%
import pandas as pd
from tqdm.notebook import tqdm
mimic4 = pd.read_csv("../raw_data/mimic4.csv")
mimic4.sort_values(by='charttime', ascending=True, inplace=True)

# %%
tmp = mimic4[mimic4["subject_id"].isin(list(df["Patient_ID"].values))]

# %%
tmp.to_csv("stage3_filtered_df.csv",index=False)

# %%
df
# Out:
#      Index  Num_Notes  Patient_ID  \
# 0        1          1    12975485
# 1        2          1    19573484
# 2        3          1    14357885
# 3        4          1    14446581
# 4        5          1    19323119
# ..     ...        ...         ...
# 145    146          1    13505645
# 146    147          1    10755497
# 147    148          1    15480536
# 148    149          1    12735382
# 149    150          1    17766160
#
#                                               Question  \
# 0    What were the clinical interventions performed...
# 1    What kind of allergy does the patient have and...
# 2    What was the patient's initial presenting cond...
# 3    What was the diagnosis of the female patient's...
# 4    What specific operative procedure did the pati...
# ..                                                 ...
# 145  What does the patient's white blood cell count...
# 146  What was the patient's main presenting issue a...
# ...

# %%
df.to_csv("stage3_step3.csv",index=False)
